# %%
import pandas as pd
import numpy as np
import glob
import os
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from scipy.stats import skew
sns.set()
warnings.filterwarnings('ignore')

# %%
# Set the directory path where the CSV files are located
file1 = pd.read_csv("ResaleFlatPricesBasedonApprovalDate19901999.csv")
file2 = pd.read_csv("ResaleFlatPricesBasedonApprovalDate2000Feb2012.csv")
file3 = pd.read_csv("ResaleFlatPricesBasedonRegistrationDateFromMar2012toDec2014.csv")
file4 = pd.read_csv("ResaleFlatPricesBasedonRegistrationDateFromJan2015toDec2016.csv")
file5 = pd.read_csv("ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv")

# %%
df = pd.concat([file1, file2, file3, file4, file5], ignore_index=True)
df
# Out:
#           month        town         flat_type block       street_name  \
# 0       1990-01  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 1       1990-01  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 2       1990-01  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 3       1990-01  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 4       1990-01  ANG MO KIO            3 ROOM   216  ANG MO KIO AVE 1
# ...         ...         ...               ...   ...               ...
# 915269  2023-12      YISHUN         EXECUTIVE   643      YISHUN ST 61
# 915270  2023-12      YISHUN         EXECUTIVE   643      YISHUN ST 61
# 915271  2023-12      YISHUN         EXECUTIVE   826      YISHUN ST 81
# 915272  2023-12      YISHUN         EXECUTIVE   834      YISHUN ST 81
# 915273  2023-12      YISHUN  MULTI-GENERATION   666      YISHUN AVE 4
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# 0          10 TO 12            31.0          IMPROVED                 1977
# 1          04 TO 06            31.0          IMPROVED                 1977
# 2          10 TO 12            31.0          IMPROVED                 1977
# 3          07 TO 09            31.0          IMPROVED                 1977
# 4          04 TO 06            73.0    NEW GENERATION                 1976
# ...             ...             ...               ...                  ...
# 915269     10 TO 12           146.0        Maisonette                 1987
# 915270     10 TO 12           142.0         Apartment                 1987
# 915271     01 TO 03           142.0         Apartment                 1988
# 915272     01 TO 03           142.0         Apartment                 1988
# 915273     01 TO 03           179.0  Multi Generation                 1987
#
#         resale_price     remaining_lease
# 0             9000.0                 NaN
# 1             6000.0                 NaN
# 2             8000.0                 NaN
# 3             6000.0                 NaN
# 4            47200.0                 NaN
# ...              ...                 ...
# 915269      838000.0  62 years 10 months
# 915270      755000.0  62 years 10 months
# 915271      780000.0  63 years 02 months
# 915272      785000.0  63 years 02 months
# 915273      975000.0   63 years 01 month
#
# [915274 rows x 11 columns]

# %% [markdown]
# # **Preprocessing**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915274 entries, 0 to 915273
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                915274 non-null  object
#  1   town                 915274 non-null  object
#  2   flat_type            915274 non-null  object
#  3   block                915274 non-null  object
#  4   street_name          915274 non-null  object
#  5   storey_range         915274 non-null  object
#  6   floor_area_sqm       915274 non-null  float64
#  7   flat_model           915274 non-null  object
#  8   lease_commence_date  915274 non-null  int64
#  9   resale_price         915274 non-null  float64
#  10  remaining_lease      206224 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 76.8+ MB

# %%
df.isna().sum()
# Out:
# month                       0
# town                        0
# flat_type                   0
# block                       0
# street_name                 0
# storey_range                0
# floor_area_sqm              0
# flat_model                  0
# lease_commence_date         0
# resale_price                0
# remaining_lease        709050
# dtype: int64

# %%
df.nunique()
# Out:
# month                   408
# town                     27
# flat_type                 8
# block                  2699
# street_name             584
# storey_range             25
# floor_area_sqm          210
# flat_model               34
# lease_commence_date      56
# resale_price           9346
# remaining_lease         720
# dtype: int64

# %%
df['flat_type'].unique()
# Out:
# array(['1 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE',
#        'MULTI GENERATION', 'MULTI-GENERATION'], dtype=object)

# %%
# Map flat type values to 'MULTI GENERATION' if it is 'MULTI-GENERATION' and update the 'flat_type' column in the dataframe.

flat_type_mappings ={Type : 'MULTI GENERATION' if Type == 'MULTI-GENERATION'  else Type  for Type in df['flat_type']}

df['flat_type'] = df['flat_type'].map(flat_type_mappings)
df['flat_type'].value_counts()
# Out:
# flat_type
# 4 ROOM              347255
# 3 ROOM              293071
# 5 ROOM              192701
# EXECUTIVE            68921
# 2 ROOM               11487
# 1 ROOM                1300
# MULTI GENERATION       539
# Name: count, dtype: int64

# %%
df['flat_model'].nunique()
# Out:
# 34

# %%
# Create a mapping to convert each flat model to its uppercase equivalent
flat_model_mappings = {model : model.upper()  for model in df['flat_model']}

df['flat_model'] = df['flat_model'].map(flat_model_mappings)

df['flat_model'].nunique()
# Out:
# 21

# %%
df['month'] = pd.to_datetime(df['month'], format = '%Y-%m').dt.to_period('M')

# %%
df['year'] = df['month'].dt.year
df['month'] = df['month'].dt.month

# %%
# Extract the minimum storey and maximum storey from 'storey_range' and convert it to integer

df['minimum_storey']=df['storey_range'].str.split(' TO ').str[0].astype(int)
df['maximum_storey']=df['storey_range'].str.split(' TO ').str[1].astype(int)
df.head()
# Out:
#    month        town flat_type block       street_name storey_range  \
# 0      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4      1  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0            31.0        IMPROVED                 1977        9000.0
# 1            31.0        IMPROVED                 1977        6000.0
# 2            31.0        IMPROVED                 1977        8000.0
# 3            31.0        IMPROVED                 1977        6000.0
# 4            73.0  NEW GENERATION                 1976       47200.0
#
#   remaining_lease  year  minimum_storey  maximum_storey
# 0             NaN  1990              10              12
# 1             NaN  1990               4               6
# 2             NaN  1990              10              12
# 3             NaN  1990               7               9
# 4             NaN  1990               4               6

# %%
df['is_remaining_lease'] = np.where(df['remaining_lease'].isna()==True, 0, 1)

# %%
# Replace NaN values in 'remaining_lease' with 'Not Specified'
df['remaining_lease'] = np.where(df['remaining_lease'].isna()==True, 'Not Specified', df['remaining_lease'])

# %%
df.isna().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# year                   0
# minimum_storey         0
# maximum_storey         0
# is_remaining_lease     0
# dtype: int64

# %%
df
# Out:
#         month        town         flat_type block       street_name  \
# 0           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 1           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 2           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 3           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 4           1  ANG MO KIO            3 ROOM   216  ANG MO KIO AVE 1
# ...       ...         ...               ...   ...               ...
# 915269     12      YISHUN         EXECUTIVE   643      YISHUN ST 61
# 915270     12      YISHUN         EXECUTIVE   643      YISHUN ST 61
# 915271     12      YISHUN         EXECUTIVE   826      YISHUN ST 81
# 915272     12      YISHUN         EXECUTIVE   834      YISHUN ST 81
# 915273     12      YISHUN  MULTI GENERATION   666      YISHUN AVE 4
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# 0          10 TO 12            31.0          IMPROVED                 1977
# 1          04 TO 06            31.0          IMPROVED                 1977
# 2          10 TO 12            31.0          IMPROVED                 1977
# 3          07 TO 09            31.0          IMPROVED                 1977
# 4          04 TO 06            73.0    NEW GENERATION                 1976
# ...             ...             ...               ...                  ...
# 915269     10 TO 12           146.0        MAISONETTE                 1987
# 915270     10 TO 12           142.0         APARTMENT                 1987
# 915271     01 TO 03           142.0         APARTMENT                 1988
# 915272     01 TO 03           142.0         APARTMENT                 1988
# 915273     01 TO 03           179.0  MULTI GENERATION                 1987
#
#         resale_price     remaining_lease  year  minimum_storey  \
# 0             9000.0       Not Specified  1990              10
# 1             6000.0       Not Specified  1990               4
# 2             8000.0       Not Specified  1990              10
# 3             6000.0       Not Specified  1990               7
# 4            47200.0       Not Specified  1990               4
# ...              ...                 ...   ...             ...
# 915269      838000.0  62 years 10 months  2023              10
# 915270      755000.0  62 years 10 months  2023              10
# 915271      780000.0  63 years 02 months  2023               1
# 915272      785000.0  63 years 02 months  2023               1
# 915273      975000.0   63 years 01 month  2023               1
#
#         maximum_storey  is_remaining_lease
# 0                   12                   0
# 1                    6                   0
# 2                   12                   0
# 3                    9                   0
# 4                    6                   0
# ...                ...                 ...
# 915269              12                   1
# 915270              12                   1
# 915271               3                   1
# 915272               3                   1
# 915273               3                   1
#
# [915274 rows x 15 columns]

# %% [markdown]
# # ***Skewness***

# %%
def skewness_plot(df, *column):
    nrow = len(column)
    plot_no=0
    for col_name in column:
        if  'sqrt' in col_name:
            title= "After Treatment"
        else:
            title = "Before Treatment"

        plt.figure(figsize=(16, 8))

        plot_no+=1
        plt.subplot(nrow, 3, plot_no)
        sns.boxplot(x=col_name, data=df)
        plt.title('Boxplot - '+ title)

        plot_no+=1
        plt.subplot(nrow, 3, plot_no)
        sns.distplot(df[col_name])
        plt.title(f'Distplot - Skewness: {skew(df[col_name])}')

        plot_no+=1
        plt.subplot(nrow, 3, plot_no)
        sns.violinplot(x=col_name, data=df)
        plt.title('Violinplot - ' + title)

    plt.tight_layout()
    
    return plt.show()

# %%
numerical_columns = ['floor_area_sqm', 'resale_price']
skewness_plot(df, *numerical_columns)

# %%
def Square_Root_Transformation(df, *column):

    for col_name in column:
        # Square Root Tansformation
        df[col_name+'_sqrt'] = np.sqrt(df[col_name])
        

    column =[i for i in df.columns if 'sqrt' in i]

    return skewness_plot(df, * column)

# %%
Square_Root_Transformation(df, *numerical_columns)

# %% [markdown]
# # ***Outlier***

# %%
df
# Out:
#         month        town         flat_type block       street_name  \
# 0           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 1           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 2           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 3           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 4           1  ANG MO KIO            3 ROOM   216  ANG MO KIO AVE 1
# ...       ...         ...               ...   ...               ...
# 915269     12      YISHUN         EXECUTIVE   643      YISHUN ST 61
# 915270     12      YISHUN         EXECUTIVE   643      YISHUN ST 61
# 915271     12      YISHUN         EXECUTIVE   826      YISHUN ST 81
# 915272     12      YISHUN         EXECUTIVE   834      YISHUN ST 81
# 915273     12      YISHUN  MULTI GENERATION   666      YISHUN AVE 4
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# 0          10 TO 12            31.0          IMPROVED                 1977
# 1          04 TO 06            31.0          IMPROVED                 1977
# 2          10 TO 12            31.0          IMPROVED                 1977
# 3          07 TO 09            31.0          IMPROVED                 1977
# 4          04 TO 06            73.0    NEW GENERATION                 1976
# ...             ...             ...               ...                  ...
# 915269     10 TO 12           146.0        MAISONETTE                 1987
# 915270     10 TO 12           142.0         APARTMENT                 1987
# 915271     01 TO 03           142.0         APARTMENT                 1988
# 915272     01 TO 03           142.0         APARTMENT                 1988
# 915273     01 TO 03           179.0  MULTI GENERATION                 1987
#
#         resale_price     remaining_lease  year  minimum_storey  \
# 0             9000.0       Not Specified  1990              10
# 1             6000.0       Not Specified  1990               4
# 2             8000.0       Not Specified  1990              10
# 3             6000.0       Not Specified  1990               7
# 4            47200.0       Not Specified  1990               4
# ...              ...                 ...   ...             ...
# 915269      838000.0  62 years 10 months  2023              10
# 915270      755000.0  62 years 10 months  2023              10
# 915271      780000.0  63 years 02 months  2023               1
# 915272      785000.0  63 years 02 months  2023               1
# 915273      975000.0   63 years 01 month  2023               1
#
#         maximum_storey  is_remaining_lease  floor_area_sqm_sqrt  \
# 0                   12                   0             5.567764
# 1                    6                   0             5.567764
# 2                   12                   0             5.567764
# 3                    9                   0             5.567764
# 4                    6                   0             8.544004
# ...                ...                 ...                  ...
# 915269              12                   1            12.083046
# 915270              12                   1            11.916375
# 915271               3                   1            11.916375
# 915272               3                   1            11.916375
# 915273               3                   1            13.379088
#
#         resale_price_sqrt
# 0               94.868330
# 1               77.459667
# 2               89.442719
# 3               77.459667
# 4              217.255610
# ...                   ...
# 915269         915.423399
# 915270         868.907360
# 915271         883.176087
# 915272         886.002257
# 915273         987.420883
#
# [915274 rows x 17 columns]

# %%
def outlier_plot(df):

    plt.figure(figsize=(16, 10))

    plt.subplot(2, 2, 1)
    sns.boxplot(x='floor_area_sqm', data=df)
    plt.title('Boxplot - floor area sqm')

    plt.subplot(2, 2, 2)
    sns.boxplot(x='floor_area_sqm_sqrt', data=df)
    plt.title('Boxplot - floor area sqm sqrt')

    plt.subplot(2, 2, 3)
    sns.boxplot(x='resale_price', data=df)
    plt.title('Boxplot - '+ 'resale price')

    plt.subplot(2, 2, 4)
    sns.boxplot(x='resale_price_sqrt', data=df)
    plt.title('Boxplot - '+ 'resale price sqrt')
    plt.tight_layout()
    
    return plt.show()

# %%
outlier_plot(df)

# %%
# Identify and handle outliers in specified numerical columns using the quantile-based method.

def outlier_quantile(df, *column):

    for col_name in column:
        #Finding the IQR
        percentile25 = df[col_name].quantile(0.25)
        percentile75 = df[col_name].quantile(0.75)
        iqr = percentile75 - percentile25

        # Define upper and lower limits for outlier detection
        upper_limit = percentile75 + 1.5 * iqr
        lower_limit = percentile25 - 1.5 * iqr

        # Cap values beyond upper and lower limits
        df[col_name] = np.where(df[col_name] > upper_limit, upper_limit, df[col_name])
        df[col_name] = np.where(df[col_name] < lower_limit, lower_limit, df[col_name])

    return outlier_plot(df)

# %%
column_name = [ 'floor_area_sqm', 'floor_area_sqm_sqrt', 'resale_price', 'resale_price_sqrt']
outlier_quantile(df, *column_name)

# %%
column_name = ['month', 'year', 'floor_area_sqm', 'floor_area_sqm_sqrt', 'lease_commence_date', 'minimum_storey','maximum_storey',
               'is_remaining_lease', 'resale_price', 'resale_price_sqrt']
sns.heatmap(df[column_name].corr(), annot= True)
# Out:
# <Axes: >

# %% [markdown]
# # ***Regression***

# %%
df1 = df.copy()
df1['remaining_lease'] = df1['remaining_lease'].astype(str)
df1
# Out:
#         month        town         flat_type block       street_name  \
# 0           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 1           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 2           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 3           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 4           1  ANG MO KIO            3 ROOM   216  ANG MO KIO AVE 1
# ...       ...         ...               ...   ...               ...
# 915269     12      YISHUN         EXECUTIVE   643      YISHUN ST 61
# 915270     12      YISHUN         EXECUTIVE   643      YISHUN ST 61
# 915271     12      YISHUN         EXECUTIVE   826      YISHUN ST 81
# 915272     12      YISHUN         EXECUTIVE   834      YISHUN ST 81
# 915273     12      YISHUN  MULTI GENERATION   666      YISHUN AVE 4
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# 0          10 TO 12            31.0          IMPROVED                 1977
# 1          04 TO 06            31.0          IMPROVED                 1977
# 2          10 TO 12            31.0          IMPROVED                 1977
# 3          07 TO 09            31.0          IMPROVED                 1977
# 4          04 TO 06            73.0    NEW GENERATION                 1976
# ...             ...             ...               ...                  ...
# 915269     10 TO 12           146.0        MAISONETTE                 1987
# 915270     10 TO 12           142.0         APARTMENT                 1987
# 915271     01 TO 03           142.0         APARTMENT                 1988
# 915272     01 TO 03           142.0         APARTMENT                 1988
# 915273     01 TO 03           173.0  MULTI GENERATION                 1987
#
#         resale_price     remaining_lease  year  minimum_storey  \
# 0             9000.0       Not Specified  1990              10
# 1             6000.0       Not Specified  1990               4
# 2             8000.0       Not Specified  1990              10
# 3             6000.0       Not Specified  1990               7
# 4            47200.0       Not Specified  1990               4
# ...              ...                 ...   ...             ...
# 915269      744800.0  62 years 10 months  2023              10
# 915270      744800.0  62 years 10 months  2023              10
# 915271      744800.0  63 years 02 months  2023               1
# 915272      744800.0  63 years 02 months  2023               1
# 915273      744800.0   63 years 01 month  2023               1
#
#         maximum_storey  is_remaining_lease  floor_area_sqm_sqrt  \
# 0                   12                   0             5.567764
# 1                    6                   0             5.567764
# 2                   12                   0             5.567764
# 3                    9                   0             5.567764
# 4                    6                   0             8.544004
# ...                ...                 ...                  ...
# 915269              12                   1            12.083046
# 915270              12                   1            11.916375
# 915271               3                   1            11.916375
# 915272               3                   1            11.916375
# 915273               3                   1            13.379088
#
#         resale_price_sqrt
# 0              130.898281
# 1              130.898281
# 2              130.898281
# 3              130.898281
# 4              217.255610
# ...                   ...
# 915269         915.423399
# 915270         868.907360
# 915271         883.176087
# 915272         886.002257
# 915273         949.702248
#
# [915274 rows x 17 columns]

# %%
df1.dtypes
# Out:
# month                    int64
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease         object
# year                     int64
# minimum_storey           int32
# maximum_storey           int32
# is_remaining_lease       int32
# floor_area_sqm_sqrt    float64
# resale_price_sqrt      float64
# dtype: object

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# Specify categorical column names for ordinal encoding
column_names = ['town', 'flat_type', 'block', 'street_name', 'storey_range', 'flat_model', 'remaining_lease']

# Dictionary to store unique values before and after ordinal encoding
unique_value ={}
for col_name in column_names:
    data = df1[col_name].unique()
    data.sort()

    df1[col_name] = enc.fit_transform(df1[[col_name]])

    globals()[col_name] = {}
    for i in df1[col_name].unique():
        globals()[col_name][data[int(i)]] = i
        unique_value[f'{col_name}'] = globals()[col_name]
    # print(globals()[col_name])
unique_value
# Out:
# {'town': {'ANG MO KIO': 0.0,
#   'BEDOK': 1.0,
#   'BISHAN': 2.0,
#   'BUKIT BATOK': 3.0,
#   'BUKIT MERAH': 4.0,
#   'BUKIT TIMAH': 6.0,
#   'CENTRAL AREA': 7.0,
#   'CHOA CHU KANG': 8.0,
#   'CLEMENTI': 9.0,
#   'GEYLANG': 10.0,
#   'HOUGANG': 11.0,
#   'JURONG EAST': 12.0,
#   'JURONG WEST': 13.0,
#   'KALLANG/WHAMPOA': 14.0,
#   'MARINE PARADE': 16.0,
#   'QUEENSTOWN': 19.0,
#   'SENGKANG': 21.0,
#   'SERANGOON': 22.0,
#   'TAMPINES': 23.0,
#   'TOA PAYOH': 24.0,
#   'WOODLANDS': 25.0,
#   'YISHUN': 26.0,
#   'LIM CHU KANG': 15.0,
#   'SEMBAWANG': 20.0,
#   'BUKIT PANJANG': 5.0,
#   'PASIR RIS': 17.0,
#   'PUNGGOL': 18.0},
#  'flat_type': {'1 ROOM': 0.0,
#   '3 ROOM': 2.0,
#   '4 ROOM': 3.0,
#   '5 ROOM': 4.0,
#   '2 ROOM': 1.0,
#   'EXECUTIVE': 5.0,
#   'MULTI GENERATION': 6.0},
#  'block': {'309': 829.0,
#   '216': 447.0,
#   '211': 430.0,
#   '202': 388.0,
#   '235': 532.0,
#   '232': 521.0,
#   '308': 825.0,
#   '220': 468.0,
#   '219': 462.0,
#   '247': 548.0,
#   '320': 883.0,
#   '252': 558.0,
#   '223': 478.0,
#   '230': 509.0,
#   '329': 921.0,
#   '313': 849.0,
#   '117': 79.0,
#   '110': 53.0,
#   '343': 981.0,
#   '345': 983.0,
#   '346': 984.0,
#   '121': 99.0,
#   '129': 135.0,
#   '130': 143.0,
#   '128': 130.0,
#   '127': 126.0,
#   '126': 121.0,
#   '403': 1109.0,
#   '404': 1114.0,
#   '405': 1117.0,
#   '417': 1160.0,
#   '418': 1162.0,
#   '419': 1166.0,
#   '441': 1237.0,
#   '442': 1242.0,
#   '443': 1247.0,
#   '444': 1252.0,
#   '450': 1271.0,
#   '435': 1213.0,
#   '433': 1207.0,
#   '434': 1210.0,
#   '424': 1172.0,
#   '425': 1177.0,
#   '466': 1317.0,
#   '471': 1339.0,
#   '474': 1352.0,
#   '570': 1661.0,
#   '586': 1691.0,
#   '455': 1291.0,
#   '465': 1316.0,
#   '463': 1311.0,
#   '564': 1654.0,
#   '560': 1647.0,
#   '558': 1644.0,
#   '559': 1645.0,
#   '538': 1609.0,
#   '534': 1604.0,
#   '601': 1723.0,
#   '603': 1732.0,
#   '604': 1736.0,
#   '608': 1747.0,
#   '611': 1751.0,
#   '505': 1496.0,
#   '503': 1487.0,
#   '610': 1750.0,
#   '607': 1746.0,
#   '524': 1572.0,
#   '513': 1530.0,
#   '643': 1861.0,
#   '542': 1614.0,
#   '548': 1627.0,
#   '550': 1634.0,
#   '639': 1846.0,
#   '637': 1837.0,
#   '330': 925.0,
#   '333': 936.0,
#   '156': 191.0,
#   '152': 186.0,
#   '178': 277.0,
#   '180': 286.0,
#   '209': 421.0,
#   '231': 518.0,
#   '254': 561.0,
#   '103': 13.0,
#   '105': 22.0,
#   '344': 982.0,
#   '324': 902.0,
#   '120': 94.0,
#   '124': 116.0,
#   '414': 1149.0,
#   '438': 1223.0,
#   '427': 1183.0,
#   '428': 1184.0,
#   '473': 1347.0,
#   '573': 1672.0,
#   '585': 1690.0,
#   '456': 1295.0,
#   '544': 1616.0,
#   '640': 1850.0,
#   '638': 1842.0,
#   '646': 1865.0,
#   '150': 183.0,
#   '179': 282.0,
#   '336': 950.0,
#   '335': 946.0,
#   '401': 1107.0,
#   '439': 1226.0,
#   '430': 1192.0,
#   '460': 1300.0,
#   '459': 1298.0,
#   '716': 2129.0,
#   '545': 1617.0,
#   '620': 1789.0,
#   '622': 1791.0,
#   '259': 577.0,
#   '101': 3.0,
#   '18': 285.0,
#   '28': 686.0,
#   '29': 734.0,
#   '30': 790.0,
#   '75': 2176.0,
#   '76': 2190.0,
#   '501': 1477.0,
#   '502': 1482.0,
#   '504': 1491.0,
#   '2': 376.0,
#   '20': 377.0,
#   '21': 425.0,
#   '59': 1703.0,
#   '58': 1684.0,
#   '55': 1633.0,
#   '22': 467.0,
#   '104': 17.0,
#   '107': 32.0,
#   '69': 2062.0,
#   '33': 924.0,
#   '46': 1299.0,
#   '116': 75.0,
#   '115': 70.0,
#   '125': 120.0,
#   '138': 157.0,
#   '87': 2447.0,
#   '100': 2.0,
#   '412': 1143.0,
#   '402': 1108.0,
#   '416': 1156.0,
#   '136': 155.0,
#   '529': 1594.0,
#   '510': 1519.0,
#   '525': 1576.0,
#   '218': 457.0,
#   '213': 439.0,
#   '532': 1602.0,
#   '533': 1603.0,
#   '536': 1607.0,
#   '537': 1608.0,
#   '44': 1231.0,
#   '540': 1612.0,
#   '702': 2111.0,
#   '615': 1765.0,
#   '712': 2125.0,
#   '50': 1475.0,
#   '54': 1611.0,
#   '606': 1744.0,
#   '616': 1769.0,
#   '15': 182.0,
#   '34': 970.0,
#   '36': 1032.0,
#   '35': 994.0,
#   '41': 1135.0,
#   '42': 1167.0,
#   '53': 1595.0,
#   '51': 1518.0,
#   '8': 2279.0,
#   '718': 2133.0,
#   '724': 2140.0,
#   '166': 226.0,
#   '71': 2122.0,
#   '82': 2353.0,
#   '78': 2215.0,
#   '79': 2260.0,
#   '80': 2280.0,
#   '134': 153.0,
#   '132': 150.0,
#   '131': 146.0,
#   '133': 151.0,
#   '89': 2491.0,
#   '62': 1788.0,
#   '422': 1170.0,
#   '507': 1505.0,
#   '508': 1510.0,
#   '517': 1542.0,
#   '95': 2601.0,
#   '93': 2570.0,
#   '43': 1191.0,
#   '543': 1615.0,
#   '547': 1622.0,
#   '708': 2117.0,
#   '707': 2116.0,
#   '713': 2126.0,
#   '609': 1748.0,
#   '61': 1749.0,
#   '56': 1646.0,
#   '165': 223.0,
#   '710': 2123.0,
#   '613': 1757.0,
#   '602': 1728.0,
#   '605': 1740.0,
#   '112': 61.0,
#   '1': 0.0,
#   '722': 2138.0,
#   '72': 2135.0,
#   '31': 835.0,
#   '111': 58.0,
#   '118': 83.0,
#   '96': 2615.0,
#   '137': 156.0,
#   '139': 162.0,
#   '725': 2141.0,
#   '24': 540.0,
#   '304': 807.0,
#   '310': 836.0,
#   '160': 205.0,
#   '161': 208.0,
#   '164': 219.0,
#   '177': 276.0,
#   '205': 403.0,
#   '248': 549.0,
#   '258': 572.0,
#   '4': 1105.0,
#   '6': 1721.0,
#   '146': 176.0,
#   '143': 173.0,
#   '145': 175.0,
#   '182': 294.0,
#   '228': 503.0,
#   '227': 498.0,
#   '244': 545.0,
#   '113': 64.0,
#   '163': 215.0,
#   '169': 239.0,
#   '204': 398.0,
#   '135': 154.0,
#   '184': 302.0,
#   '225': 488.0,
#   '123': 110.0,
#   '307': 820.0,
#   '221': 472.0,
#   '214': 443.0,
#   '142': 172.0,
#   '140': 166.0,
#   '141': 171.0,
#   '7': 2104.0,
#   '40': 1106.0,
#   '77': 2203.0,
#   '119': 88.0,
#   '114': 69.0,
#   '5': 1474.0,
#   '12': 93.0,
#   '16': 204.0,
#   '13': 142.0,
#   '108': 37.0,
#   '102': 8.0,
#   '106': 27.0,
#   '63': 1814.0,
#   '60': 1722.0,
#   '3': 789.0,
#   '19': 332.0,
#   '26': 583.0,
#   '37': 1060.0,
#   '47': 1334.0,
#   '109': 41.0,
#   '57': 1660.0,
#   '48': 1369.0,
#   '73': 2146.0,
#   '66': 1916.0,
#   '264': 600.0,
#   '271': 641.0,
#   '664': 1937.0,
#   '9': 2533.0,
#   '10': 1.0,
#   '663': 1932.0,
#   '662': 1927.0,
#   '335B': 948.0,
#   '632': 1817.0,
#   '633': 1821.0,
#   '642': 1856.0,
#   '440': 1232.0,
#   '509': 1514.0,
#   '363': 1042.0,
#   '365': 1048.0,
#   '334': 941.0,
#   '323': 897.0,
#   '322': 892.0,
#   '326': 911.0,
#   '314': 854.0,
#   '312': 845.0,
#   '354': 1012.0,
#   '506': 1501.0,
#   '305': 810.0,
#   '306': 815.0,
#   '303': 802.0,
#   '431': 1197.0,
#   '339': 965.0,
#   '515': 1536.0,
#   '520': 1558.0,
#   '703': 2112.0,
#   '704': 2113.0,
#   '711': 2124.0,
#   '705': 2114.0,
#   '731': 2148.0,
#   '728': 2144.0,
#   '706': 2115.0,
#   '411': 1140.0,
#   '315': 859.0,
#   '311': 840.0,
#   '301': 792.0,
#   '729': 2145.0,
#   '371': 1062.0,
#   '415': 1152.0,
#   '413': 1146.0,
#   '337': 955.0,
#   '717': 2130.0,
#   '723': 2139.0,
#   '201': 382.0,
#   '81': 2320.0,
#   '45': 1270.0,
#   '85': 2399.0,
#   '98': 2644.0,
#   '99': 2674.0,
#   '65': 1875.0,
#   '23': 508.0,
#   '67': 1964.0,
#   '49': 1403.0,
#   '39': 1089.0,
#   '38': 1074.0,
#   '17': 243.0,
#   '319': 878.0,
#   '318': 873.0,
#   '327': 916.0,
#   '410': 1136.0,
#   '239': 537.0,
#   '154': 189.0,
#   '341': 974.0,
#   '352': 1004.0,
#   '251': 557.0,
#   '302': 797.0,
#   '234': 529.0,
#   '237': 535.0,
#   '233': 525.0,
#   '242': 543.0,
#   '243': 544.0,
#   '257': 568.0,
#   '210': 426.0,
#   '208': 417.0,
#   '316': 863.0,
#   '408': 1128.0,
#   '240': 541.0,
#   '331': 928.0,
#   '406': 1121.0,
#   '167': 229.0,
#   '168': 234.0,
#   '170': 244.0,
#   '172': 252.0,
#   '185': 306.0,
#   '186': 311.0,
#   '187': 316.0,
#   '212': 435.0,
#   '215': 444.0,
#   '516': 1541.0,
#   '511': 1522.0,
#   '457': 1296.0,
#   '490': 1404.0,
#   '489': 1397.0,
#   '487': 1388.0,
#   '485': 1379.0,
#   '476': 1358.0,
#   '477': 1363.0,
#   '527': 1585.0,
#   '535': 1605.0,
#   '484': 1374.0,
#   '491': 1409.0,
#   '481': 1371.0,
#   '217': 452.0,
#   '448': 1263.0,
#   '446': 1256.0,
#   '447': 1260.0,
#   '554': 1640.0,
#   '551': 1637.0,
#   '458': 1297.0,
#   '436': 1217.0,
#   '452': 1282.0,
#   '539': 1610.0,
#   '198': 363.0,
#   '203': 392.0,
#   '407': 1125.0,
#   '469': 1330.0,
#   '468': 1325.0,
#   '801': 2282.0,
#   '97': 2628.0,
#   '11': 52.0,
#   '68': 2009.0,
#   '94': 2586.0,
#   '14': 165.0,
#   '84': 2379.0,
#   '83': 2367.0,
#   '52': 1557.0,
#   '807': 2305.0,
#   '461': 1301.0,
#   '32': 882.0,
#   '171': 248.0,
#   '173': 256.0,
#   '88': 2467.0,
#   '86': 2423.0,
#   '74': 2158.0,
#   '25': 551.0,
#   '267': 618.0,
#   '269': 627.0,
#   '924': 2562.0,
#   '925': 2563.0,
#   '817': 2342.0,
#   '818': 2346.0,
#   '808': 2309.0,
#   '809': 2314.0,
#   '285': 699.0,
#   '287': 709.0,
#   '274': 656.0,
#   '291': 743.0,
#   '293': 753.0,
#   '262': 594.0,
#   '914': 2550.0,
#   '250': 552.0,
#   '226': 492.0,
#   '236': 533.0,
#   '270': 637.0,
#   '420': 1168.0,
#   '157': 192.0,
#   '820': 2354.0,
#   '819': 2350.0,
#   '813': 2331.0,
#   '810': 2321.0,
#   '266': 613.0,
#   '265': 607.0,
#   '286': 704.0,
#   '272': 646.0,
#   '275': 661.0,
#   '295': 760.0,
#   '261': 589.0,
#   '913': 2549.0,
#   '910': 2546.0,
#   '253': 559.0,
#   '277': 671.0,
#   '928': 2566.0,
#   '832': 2371.0,
#   '838': 2377.0,
#   '839': 2378.0,
#   '159': 202.0,
#   '812': 2327.0,
#   '811': 2324.0,
#   '294': 758.0,
#   '432': 1202.0,
#   '816': 2339.0,
#   '289': 722.0,
#   '298': 775.0,
#   '912': 2548.0,
#   '278': 676.0,
#   '279': 680.0,
#   '245': 546.0,
#   '149': 179.0,
#   '148': 178.0,
#   '91': 2545.0,
#   '27': 636.0,
#   '85A': 2420.0,
#   '85B': 2421.0,
#   '206': 407.0,
#   '193': 343.0,
#   '200': 378.0,
#   '1A': 369.0,
#   '162': 211.0,
#   '701': 2110.0,
#   '736': 2153.0,
#   '742': 2161.0,
#   '276': 666.0,
#   '751': 2178.0,
#   '752': 2179.0,
#   '733': 2150.0,
#   '740': 2159.0,
#   '280': 687.0,
#   '772': 2206.0,
#   '229': 507.0,
#   '238': 536.0,
#   '255': 562.0,
#   '256': 563.0,
#   '328': 920.0,
#   '348': 988.0,
#   '571': 1665.0,
#   '584': 1689.0,
#   '454': 1290.0,
#   '575': 1679.0,
#   '561': 1649.0,
#   '512': 1526.0,
#   '523': 1567.0,
#   '644': 1862.0,
#   '621': 1790.0,
#   '625': 1803.0,
#   '155': 190.0,
#   '470': 1335.0,
#   '565': 1655.0,
#   '546': 1618.0,
#   '612': 1752.0,
#   '648': 1867.0,
#   '70': 2105.0,
#   '122': 104.0,
#   '426': 1178.0,
#   '530': 1596.0,
#   '519': 1552.0,
#   '526': 1580.0,
#   '626': 1806.0,
#   '709': 2118.0,
#   '719': 2134.0,
#   '207': 412.0,
#   '175': 266.0,
#   '249': 550.0,
#   '260': 584.0,
#   '183': 297.0,
#   '641': 1852.0,
#   '362': 1038.0,
#   '409': 1132.0,
#   '429': 1187.0,
#   '518': 1547.0,
#   '449': 1267.0,
#   '379': 1073.0,
#   '359': 1028.0,
#   '347': 985.0,
#   '342': 977.0,
#   '340': 971.0,
#   '846': 2393.0,
#   '317': 868.0,
#   '321': 888.0,
#   '325': 907.0,
#   '357': 1023.0,
#   '241': 542.0,
#   '225A': 489.0,
#   '462': 1306.0,
#   '475': 1353.0,
#   '528': 1590.0,
#   '480': 1370.0,
#   '514': 1535.0,
#   '437': 1222.0,
#   '451': 1279.0,
#   '486': 1384.0,
#   '199': 364.0,
#   '64': 1849.0,
#   '153': 187.0,
#   '90': 2534.0,
#   '224': 483.0,
#   '814': 2334.0,
#   '283': 697.0,
#   '297': 770.0,
#   '848': 2395.0,
#   '831': 2370.0,
#   '281': 690.0,
#   '273': 651.0,
#   '916': 2552.0,
#   '902': 2535.0,
#   '921': 2559.0,
#   '934': 2578.0,
#   '268': 622.0,
#   '805': 2299.0,
#   '833': 2372.0,
#   '804': 2296.0,
#   '903': 2536.0,
#   '932': 2573.0,
#   '151': 185.0,
#   '147': 177.0,
#   '85C': 2422.0,
#   '174': 261.0,
#   '195': 347.0,
#   '222': 476.0,
#   '741': 2160.0,
#   '756': 2183.0,
#   '390': 1090.0,
#   '737': 2154.0,
#   '726': 2142.0,
#   '358': 1027.0,
#   '421': 1169.0,
#   '445': 1253.0,
#   '587': 1692.0,
#   '464': 1315.0,
#   '557': 1643.0,
#   '549': 1630.0,
#   '624': 1799.0,
#   '631': 1816.0,
#   '572': 1669.0,
#   '563': 1653.0,
#   '552': 1638.0,
#   '522': 1563.0,
#   '614': 1762.0,
#   '715': 2128.0,
#   '714': 2127.0,
#   '144': 174.0,
#   '335A': 947.0,
#   '661': 1922.0,
#   '269B': 629.0,
#   '634': 1826.0,
#   '730': 2147.0,
#   '338': 960.0,
#   '349': 993.0,
#   '351': 999.0,
#   '353': 1008.0,
#   '246': 547.0,
#   '521': 1562.0,
#   '488': 1392.0,
#   '478': 1367.0,
#   '555': 1641.0,
#   '556': 1642.0,
#   '27A': 684.0,
#   '23A': 538.0,
#   '907': 2540.0,
#   '282': 693.0,
#   '292': 749.0,
#   '935': 2579.0,
#   '263': 599.0,
#   '933': 2576.0,
#   '926': 2564.0,
#   '922': 2560.0,
#   '191': 336.0,
#   '732': 2149.0,
#   '158': 197.0,
#   '727': 2143.0,
#   '721': 2137.0,
#   '284': 698.0,
#   '759': 2186.0,
#   '858': 2415.0,
#   '576': 1680.0,
#   '578': 1682.0,
#   '541': 1613.0,
#   '623': 1795.0,
#   '332': 932.0,
#   '423': 1171.0,
#   '176': 271.0,
#   '181': 291.0,
#   '668': 1954.0,
#   '364': 1045.0,
#   '374': 1065.0,
#   '350': 995.0,
#   '373': 1064.0,
#   '381': 1076.0,
#   '355': 1017.0,
#   '219A': 463.0,
#   '531': 1601.0,
#   '483': 1373.0,
#   '553': 1639.0,
#   '909': 2542.0,
#   '930': 2571.0,
#   '915': 2551.0,
#   '911': 2547.0,
#   '931': 2572.0,
#   '815': 2335.0,
#   '194': 344.0,
#   '2A': 785.0,
#   '754': 2181.0,
#   '749': 2174.0,
#   '618': 1775.0,
#   '92': 2557.0,
#   '628': 1808.0,
#   '472': 1343.0,
#   '39A': 1100.0,
#   '23B': 539.0,
#   '806': 2304.0,
#   '837': 2376.0,
#   '290': 735.0,
#   '296': 764.0,
#   '857': 2412.0,
#   '735': 2152.0,
#   '746': 2165.0,
#   '649': 1872.0,
#   '635': 1829.0,
#   '636': 1833.0,
#   '367': 1056.0,
#   '360': 1033.0,
#   '376': 1067.0,
#   '854': 2404.0,
#   '288': 714.0,
#   '747': 2166.0,
#   '738': 2155.0,
#   '768': 2200.0,
#   '757': 2184.0,
#   '467': 1322.0,
#   '562': 1652.0,
#   '617': 1770.0,
#   '627': 1807.0,
#   '361': 1037.0,
#   '368': 1058.0,
#   '370': 1061.0,
#   '479': 1368.0,
#   '168A': 235.0,
#   '852': 2402.0,
#   '745': 2164.0,
#   '771': 2205.0,
#   '766': 2198.0,
#   '773': 2207.0,
#   '755': 2182.0,
#   '758': 2185.0,
#   '577': 1681.0,
#   '619': 1780.0,
#   '720': 2136.0,
#   '377': 1071.0,
#   '356': 1019.0,
#   '842': 2382.0,
#   '453': 1285.0,
#   '803': 2291.0,
#   '937': 2581.0,
#   '762': 2193.0,
#   '739': 2156.0,
#   '774': 2208.0,
#   '760': 2191.0,
#   '366': 1053.0,
#   '269A': 628.0,
#   '375': 1066.0,
#   '844': 2391.0,
#   '48A': 1402.0,
#   '734': 2151.0,
#   '778': 2212.0,
#   '197': 358.0,
#   '369': 1059.0,
#   '322A': 893.0,
#   '929': 2567.0,
#   '830': 2368.0,
#   '856': 2406.0,
#   '764': 2195.0,
#   '744': 2163.0,
#   '684': 2029.0,
#   '908': 2541.0,
#   '765': 2197.0,
#   '686': 2038.0,
#   '683': 2024.0,
#   '840': 2380.0,
#   '783': 2230.0,
#   '784': 2235.0,
#   '750': 2177.0,
#   '770': 2204.0,
#   '495': 1437.0,
#   '835': 2374.0,
#   '685': 2034.0,
#   '682': 2019.0,
#   '853': 2403.0,
#   '753': 2180.0,
#   '781': 2223.0,
#   '775': 2209.0,
#   '657': 1903.0,
#   '776': 2210.0,
#   '498': 1458.0,
#   '489A': 1398.0,
#   '767': 2199.0,
#   '872': 2454.0,
#   '880': 2468.0,
#   '874': 2456.0,
#   '380': 1075.0,
#   '677': 1995.0,
#   '860B': 2426.0,
#   '870': 2448.0,
#   '871': 2450.0,
#   '865': 2436.0,
#   '866': 2437.0,
#   '879': 2464.0,
#   '797': 2270.0,
#   '875': 2458.0,
#   '389': 1084.0,
#   '850': 2400.0,
#   '920': 2558.0,
#   '387': 1082.0,
#   '392': 1092.0,
#   '904': 2537.0,
#   '949': 2596.0,
#   '867A': 2439.0,
#   '395': 1095.0,
#   '396': 1096.0,
#   '822': 2356.0,
#   '863B': 2433.0,
#   '487A': 1389.0,
#   '886': 2475.0,
#   '873': 2455.0,
#   '670': 1965.0,
#   '899': 2526.0,
#   '898A': 2524.0,
#   '355A': 1018.0,
#   '692': 2075.0,
#   '978': 2637.0,
#   '897A': 2520.0,
#   '887': 2480.0,
#   '863A': 2432.0,
#   '133A': 152.0,
#   '939': 2583.0,
#   '905': 2538.0,
#   '927': 2565.0,
#   '861A': 2428.0,
#   '894': 2506.0,
#   '350A': 996.0,
#   '679': 2005.0,
#   '936': 2580.0,
#   '919': 2555.0,
#   '894A': 2507.0,
#   '899A': 2527.0,
#   '896': 2515.0,
#   '886A': 2476.0,
#   '188': 319.0,
#   '923': 2561.0,
#   '201A': 383.0,
#   '888': 2484.0,
#   '494C': 1431.0,
#   '895A': 2512.0,
#   '896A': 2516.0,
#   '938': 2582.0,
#   '654': 1891.0,
#   '943': 2590.0,
#   '940': 2587.0,
#   '942': 2589.0,
#   '398': 1098.0,
#   '769': 2201.0,
#   '966': 2622.0,
#   '945': 2592.0,
#   '889': 2486.0,
#   '941': 2588.0,
#   '795A': 2267.0,
#   '947': 2594.0,
#   '889A': 2487.0,
#   '871A': 2451.0,
#   '887A': 2481.0,
#   '946': 2593.0,
#   '874A': 2457.0,
#   '918': 2554.0,
#   '888A': 2485.0,
#   '869': 2444.0,
#   '976': 2635.0,
#   '979': 2640.0,
#   '567': 1657.0,
#   '485B': 1381.0,
#   '10F': 51.0,
#   '150A': 184.0,
#   '948': 2595.0,
#   '230C': 511.0,
#   '230J': 517.0,
#   '43A': 1230.0,
#   '953': 2605.0,
#   '488A': 1393.0,
#   '491B': 1411.0,
#   '492C': 1420.0,
#   '486B': 1386.0,
#   '495E': 1442.0,
#   '789': 2259.0,
#   '980': 2645.0,
#   '823': 2357.0,
#   '974': 2633.0,
#   '489C': 1400.0,
#   '496B': 1444.0,
#   '217A': 453.0,
#   '965': 2621.0,
#   '975': 2634.0,
#   '880A': 2469.0,
#   '488B': 1394.0,
#   '495F': 1443.0,
#   '952': 2604.0,
#   '506B': 1503.0,
#   '496E': 1447.0,
#   '491F': 1415.0,
#   '94B': 2597.0,
#   '961': 2617.0,
#   '830A': 2369.0,
#   '842D': 2385.0,
#   '487B': 1390.0,
#   '491H': 1417.0,
#   ...},
#  'street_name': {'ANG MO KIO AVE 1': 13.0,
#   'ANG MO KIO AVE 3': 16.0,
#   'ANG MO KIO AVE 4': 17.0,
#   'ANG MO KIO AVE 10': 14.0,
#   'ANG MO KIO AVE 5': 18.0,
#   'ANG MO KIO AVE 8': 20.0,
#   'ANG MO KIO AVE 6': 19.0,
#   'ANG MO KIO AVE 9': 21.0,
#   'ANG MO KIO AVE 2': 15.0,
#   'BEDOK RESERVOIR RD': 45.0,
#   'BEDOK NTH ST 3': 42.0,
#   'BEDOK STH RD': 50.0,
#   'NEW UPP CHANGI RD': 340.0,
#   'BEDOK NTH RD': 39.0,
#   'BEDOK STH AVE 1': 47.0,
#   'CHAI CHEE RD': 115.0,
#   'CHAI CHEE DR': 114.0,
#   'BEDOK NTH AVE 4': 38.0,
#   'BEDOK STH AVE 3': 49.0,
#   'BEDOK STH AVE 2': 48.0,
#   'BEDOK NTH ST 2': 41.0,
#   'BEDOK NTH ST 4': 43.0,
#   'BEDOK NTH AVE 2': 36.0,
#   'BEDOK NTH AVE 3': 37.0,
#   'BEDOK NTH AVE 1': 35.0,
#   'BEDOK NTH ST 1': 40.0,
#   'CHAI CHEE ST': 116.0,
#   'SIN MING RD': 437.0,
#   'SHUNFU RD': 425.0,
#   'BT BATOK ST 11': 70.0,
#   'BT BATOK WEST AVE 8': 86.0,
#   'BT BATOK WEST AVE 6': 84.0,
#   'BT BATOK ST 21': 71.0,
#   'BT BATOK EAST AVE 5': 68.0,
#   'BT BATOK EAST AVE 4': 67.0,
#   'HILLVIEW AVE': 200.0,
#   'BT BATOK CTRL': 65.0,
#   'BT BATOK ST 31': 75.0,
#   'BT BATOK EAST AVE 3': 66.0,
#   'TAMAN HO SWEE': 448.0,
#   'TELOK BLANGAH CRES': 487.0,
#   'BEO CRES': 52.0,
#   'TELOK BLANGAH DR': 488.0,
#   'DEPOT RD': 166.0,
#   'TELOK BLANGAH RISE': 490.0,
#   'JLN BT MERAH': 236.0,
#   'HENDERSON RD': 199.0,
#   'INDUS RD': 228.0,
#   'BT MERAH VIEW': 90.0,
#   'HENDERSON CRES': 198.0,
#   'BT PURMEI RD': 92.0,
#   'TELOK BLANGAH HTS': 489.0,
#   'EVERTON PK': 178.0,
#   'KG BAHRU HILL': 292.0,
#   'REDHILL CL': 385.0,
#   'HOY FATT RD': 226.0,
#   'HAVELOCK RD': 197.0,
#   'JLN KLINIK': 241.0,
#   'JLN RUMAH TINGGI': 248.0,
#   'JLN BT HO SWEE': 235.0,
#   'KIM CHENG ST': 294.0,
#   'MOH GUAN TER': 335.0,
#   'TELOK BLANGAH WAY': 492.0,
#   'KIM TIAN RD': 299.0,
#   'KIM TIAN PL': 298.0,
#   'EMPRESS RD': 175.0,
#   "QUEEN'S RD": 382.0,
#   'FARRER RD': 181.0,
#   'JLN KUKOH': 242.0,
#   'OUTRAM PK': 345.0,
#   'SHORT ST': 424.0,
#   'SELEGIE RD': 397.0,
#   'UPP CROSS ST': 505.0,
#   'WATERLOO ST': 510.0,
#   'QUEEN ST': 380.0,
#   'BUFFALO RD': 97.0,
#   'ROWELL RD': 393.0,
#   'ROCHOR RD': 392.0,
#   'BAIN ST': 30.0,
#   'SMITH ST': 438.0,
#   'VEERASAMY RD': 509.0,
#   'TECK WHYE AVE': 484.0,
#   'TECK WHYE LANE': 486.0,
#   'CLEMENTI AVE 3': 143.0,
#   'WEST COAST DR': 512.0,
#   'CLEMENTI AVE 2': 142.0,
#   'CLEMENTI AVE 5': 145.0,
#   'CLEMENTI AVE 4': 144.0,
#   'CLEMENTI AVE 1': 141.0,
#   'WEST COAST RD': 513.0,
#   'CLEMENTI WEST ST 1': 151.0,
#   'CLEMENTI WEST ST 2': 152.0,
#   'CLEMENTI ST 13': 149.0,
#   "C'WEALTH AVE WEST": 99.0,
#   'CLEMENTI AVE 6': 146.0,
#   'CLEMENTI ST 14': 150.0,
#   'CIRCUIT RD': 139.0,
#   'MACPHERSON LANE': 322.0,
#   'JLN PASAR BARU': 246.0,
#   'GEYLANG SERAI': 192.0,
#   'EUNOS CRES': 176.0,
#   'SIMS DR': 434.0,
#   'ALJUNIED CRES': 5.0,
#   'GEYLANG EAST AVE 1': 189.0,
#   'DAKOTA CRES': 163.0,
#   'PINE CL': 366.0,
#   'HAIG RD': 196.0,
#   'BALAM RD': 31.0,
#   'JLN DUA': 238.0,
#   'GEYLANG EAST CTRL': 191.0,
#   'EUNOS RD 5': 177.0,
#   'HOUGANG AVE 3': 208.0,
#   'HOUGANG AVE 5': 210.0,
#   'HOUGANG AVE 1': 205.0,
#   'HOUGANG ST 22': 218.0,
#   'HOUGANG AVE 10': 206.0,
#   'LOR AH SOO': 318.0,
#   'HOUGANG ST 11': 216.0,
#   'HOUGANG AVE 7': 212.0,
#   'HOUGANG ST 21': 217.0,
#   'TEBAN GDNS RD': 483.0,
#   'JURONG EAST AVE 1': 255.0,
#   'JURONG EAST ST 32': 260.0,
#   'JURONG EAST ST 13': 256.0,
#   'JURONG EAST ST 21': 257.0,
#   'JURONG EAST ST 24': 258.0,
#   'JURONG EAST ST 31': 259.0,
#   'PANDAN GDNS': 347.0,
#   'YUNG KUANG RD': 579.0,
#   'HO CHING RD': 201.0,
#   'HU CHING RD': 227.0,
#   'BOON LAY DR': 61.0,
#   'BOON LAY AVE': 60.0,
#   'BOON LAY PL': 62.0,
#   'JURONG WEST ST 52': 271.0,
#   'JURONG WEST ST 41': 268.0,
#   'JURONG WEST AVE 1': 261.0,
#   'JURONG WEST ST 42': 269.0,
#   'JLN BATU': 233.0,
#   "ST. GEORGE'S RD": 441.0,
#   'NTH BRIDGE RD': 342.0,
#   'FRENCH RD': 186.0,
#   'BEACH RD': 33.0,
#   'WHAMPOA DR': 514.0,
#   'UPP BOON KENG RD': 504.0,
#   'BENDEMEER RD': 51.0,
#   'WHAMPOA WEST': 517.0,
#   'LOR LIMAU': 320.0,
#   'KALLANG BAHRU': 285.0,
#   'GEYLANG BAHRU': 188.0,
#   'DORSET RD': 167.0,
#   'OWEN RD': 346.0,
#   'KG ARANG RD': 291.0,
#   'JLN BAHAGIA': 232.0,
#   'MOULMEIN RD': 338.0,
#   'TOWNER RD': 501.0,
#   'JLN RAJAH': 247.0,
#   'KENT RD': 290.0,
#   'AH HOOD RD': 2.0,
#   "KING GEORGE'S AVE": 300.0,
#   'CRAWFORD LANE': 162.0,
#   'MARINE CRES': 324.0,
#   'MARINE DR': 325.0,
#   'MARINE TER': 327.0,
#   "C'WEALTH CL": 100.0,
#   "C'WEALTH DR": 102.0,
#   'TANGLIN HALT RD': 481.0,
#   "C'WEALTH CRES": 101.0,
#   'DOVER RD': 170.0,
#   'MARGARET DR': 323.0,
#   'GHIM MOH RD': 194.0,
#   'DOVER CRES': 169.0,
#   'STIRLING RD': 442.0,
#   'MEI LING ST': 334.0,
#   'HOLLAND CL': 203.0,
#   'HOLLAND AVE': 202.0,
#   'HOLLAND DR': 204.0,
#   'DOVER CL EAST': 168.0,
#   'SELETAR WEST FARMWAY 6': 398.0,
#   'LOR LEW LIAN': 319.0,
#   'SERANGOON NTH AVE 1': 420.0,
#   'SERANGOON AVE 2': 415.0,
#   'SERANGOON AVE 4': 417.0,
#   'SERANGOON CTRL': 418.0,
#   'TAMPINES ST 11': 458.0,
#   'TAMPINES ST 21': 460.0,
#   'TAMPINES ST 91': 480.0,
#   'TAMPINES ST 81': 475.0,
#   'TAMPINES AVE 4': 450.0,
#   'TAMPINES ST 22': 461.0,
#   'TAMPINES ST 12': 459.0,
#   'TAMPINES ST 23': 462.0,
#   'TAMPINES ST 24': 463.0,
#   'TAMPINES ST 41': 467.0,
#   'TAMPINES ST 82': 476.0,
#   'TAMPINES ST 83': 477.0,
#   'TAMPINES AVE 5': 451.0,
#   'LOR 2 TOA PAYOH': 310.0,
#   'LOR 8 TOA PAYOH': 317.0,
#   'LOR 1 TOA PAYOH': 308.0,
#   'LOR 5 TOA PAYOH': 314.0,
#   'LOR 3 TOA PAYOH': 312.0,
#   'LOR 7 TOA PAYOH': 316.0,
#   'TOA PAYOH EAST': 497.0,
#   'LOR 4 TOA PAYOH': 313.0,
#   'TOA PAYOH CTRL': 496.0,
#   'TOA PAYOH NTH': 498.0,
#   'POTONG PASIR AVE 3': 370.0,
#   'POTONG PASIR AVE 1': 368.0,
#   'UPP ALJUNIED LANE': 503.0,
#   'JOO SENG RD': 254.0,
#   'MARSILING LANE': 330.0,
#   'MARSILING DR': 329.0,
#   'MARSILING RISE': 332.0,
#   'MARSILING CRES': 328.0,
#   'WOODLANDS CTR RD': 526.0,
#   'WOODLANDS ST 13': 545.0,
#   'WOODLANDS ST 11': 544.0,
#   'YISHUN RING RD': 563.0,
#   'YISHUN AVE 5': 557.0,
#   'YISHUN ST 72': 574.0,
#   'YISHUN ST 11': 564.0,
#   'YISHUN ST 21': 566.0,
#   'YISHUN ST 22': 567.0,
#   'YISHUN AVE 3': 555.0,
#   'CHAI CHEE AVE': 113.0,
#   'ZION RD': 583.0,
#   'LENGKOK BAHRU': 303.0,
#   'SPOTTISWOODE PK RD': 439.0,
#   'NEW MKT RD': 339.0,
#   'TG PAGAR PLAZA': 494.0,
#   'KELANTAN RD': 289.0,
#   'PAYA LEBAR WAY': 363.0,
#   'UBI AVE 1': 502.0,
#   'SIMS AVE': 433.0,
#   'YUNG PING RD': 581.0,
#   'TAO CHING RD': 482.0,
#   'GLOUCESTER RD': 195.0,
#   'BOON KENG RD': 59.0,
#   'WHAMPOA STH': 516.0,
#   'CAMBRIDGE RD': 103.0,
#   'TAMPINES ST 42': 468.0,
#   'LOR 6 TOA PAYOH': 315.0,
#   'KIM KEAT AVE': 295.0,
#   'YISHUN AVE 6': 558.0,
#   'YISHUN AVE 9': 560.0,
#   'YISHUN ST 71': 573.0,
#   'BT BATOK ST 32': 76.0,
#   'SILAT AVE': 426.0,
#   'TIONG BAHRU RD': 495.0,
#   'SAGO LANE': 394.0,
#   "ST. GEORGE'S LANE": 440.0,
#   'LIM CHU KANG RD': 305.0,
#   "C'WEALTH AVE": 98.0,
#   "QUEEN'S CL": 381.0,
#   'SERANGOON AVE 3': 416.0,
#   'POTONG PASIR AVE 2': 369.0,
#   'WOODLANDS AVE 1': 518.0,
#   'YISHUN AVE 4': 556.0,
#   'LOWER DELTA RD': 321.0,
#   'NILE RD': 341.0,
#   'JLN MEMBINA BARAT': 245.0,
#   'JLN BERSEH': 234.0,
#   'CHANDER RD': 117.0,
#   'CASSIA CRES': 112.0,
#   'OLD AIRPORT RD': 343.0,
#   'ALJUNIED RD': 6.0,
#   'BUANGKOK STH FARMWAY 1': 96.0,
#   'BT BATOK ST 33': 77.0,
#   'ALEXANDRA RD': 3.0,
#   'CHIN SWEE RD': 119.0,
#   'SIMS PL': 435.0,
#   'HOUGANG AVE 2': 207.0,
#   'HOUGANG AVE 8': 213.0,
#   'SEMBAWANG RD': 402.0,
#   'SIMEI ST 1': 429.0,
#   'BT BATOK ST 34': 78.0,
#   'BT MERAH CTRL': 88.0,
#   'LIM LIAK ST': 306.0,
#   'JLN TENTERAM': 251.0,
#   'WOODLANDS ST 32': 547.0,
#   'SIN MING AVE': 436.0,
#   'BT BATOK ST 52': 80.0,
#   'DELTA AVE': 165.0,
#   'PIPIT RD': 367.0,
#   'HOUGANG AVE 4': 209.0,
#   'QUEENSWAY': 383.0,
#   'YISHUN ST 61': 572.0,
#   'BISHAN ST 12': 54.0,
#   "JLN MA'MOR": 243.0,
#   'TAMPINES ST 44': 470.0,
#   'TAMPINES ST 43': 469.0,
#   'BISHAN ST 13': 55.0,
#   'JLN DUSUN': 239.0,
#   'YISHUN AVE 2': 554.0,
#   'JOO CHIAT RD': 253.0,
#   'EAST COAST RD': 171.0,
#   'REDHILL RD': 387.0,
#   'KIM PONG RD': 297.0,
#   'RACE COURSE RD': 384.0,
#   'KRETA AYER RD': 302.0,
#   'HOUGANG ST 61': 223.0,
#   'TESSENSOHN RD': 493.0,
#   'MARSILING RD': 331.0,
#   'YISHUN ST 81': 575.0,
#   'BT BATOK ST 51': 79.0,
#   'BT BATOK WEST AVE 4': 82.0,
#   'BT BATOK WEST AVE 2': 81.0,
#   'JURONG WEST ST 91': 282.0,
#   'JURONG WEST ST 81': 281.0,
#   'GANGSA RD': 187.0,
#   'MCNAIR RD': 333.0,
#   'SIMEI ST 4': 431.0,
#   'YISHUN AVE 7': 559.0,
#   'SERANGOON NTH AVE 2': 421.0,
#   'YISHUN AVE 11': 553.0,
#   'BANGKIT RD': 32.0,
#   'JURONG WEST ST 73': 278.0,
#   'OUTRAM HILL': 344.0,
#   'HOUGANG AVE 6': 211.0,
#   'PASIR RIS ST 12': 354.0,
#   'PENDING RD': 364.0,
#   'PETIR RD': 365.0,
#   'LOR 3 GEYLANG': 311.0,
#   'BISHAN ST 11': 53.0,
#   'PASIR RIS DR 6': 352.0,
#   'BISHAN ST 23': 57.0,
#   'JURONG WEST ST 92': 283.0,
#   'PASIR RIS ST 11': 353.0,
#   'YISHUN CTRL': 561.0,
#   'BISHAN ST 22': 56.0,
#   'SIMEI RD': 428.0,
#   'TAMPINES ST 84': 478.0,
#   'BT PANJANG RING RD': 91.0,
#   'JURONG WEST ST 93': 284.0,
#   'FAJAR RD': 179.0,
#   'WOODLANDS ST 81': 549.0,
#   'CHOA CHU KANG CTRL': 127.0,
#   'PASIR RIS ST 51': 358.0,
#   'HOUGANG ST 52': 222.0,
#   'CASHEW RD': 111.0,
#   'TOH YI DR': 500.0,
#   'HOUGANG CTRL': 215.0,
#   'KG KAYU RD': 293.0,
#   'TAMPINES AVE 8': 453.0,
#   'TAMPINES ST 45': 471.0,
#   'SIMEI ST 2': 430.0,
#   'WOODLANDS AVE 3': 519.0,
#   'LENGKONG TIGA': 304.0,
#   'WOODLANDS ST 82': 550.0,
#   'SERANGOON NTH AVE 4': 423.0,
#   'SERANGOON CTRL DR': 419.0,
#   'BRIGHT HILL DR': 64.0,
#   'SAUJANA RD': 395.0,
#   'CHOA CHU KANG AVE 3': 122.0,
#   'TAMPINES AVE 9': 454.0,
#   'JURONG WEST ST 51': 270.0,
#   'YUNG HO RD': 578.0,
#   'SERANGOON AVE 1': 414.0,
#   'PASIR RIS ST 41': 357.0,
#   'GEYLANG EAST AVE 2': 190.0,
#   'CHOA CHU KANG AVE 2': 121.0,
#   'KIM KEAT LINK': 296.0,
#   'PASIR RIS DR 4': 351.0,
#   'PASIR RIS ST 21': 356.0,
#   'SENG POH RD': 405.0,
#   'HOUGANG ST 51': 221.0,
#   'JURONG WEST ST 72': 277.0,
#   'JURONG WEST ST 71': 276.0,
#   'PASIR RIS ST 52': 359.0,
#   'TAMPINES ST 32': 464.0,
#   'CHOA CHU KANG AVE 4': 123.0,
#   'CHOA CHU KANG LOOP': 129.0,
#   'JLN TENAGA': 250.0,
#   'TAMPINES CTRL 1': 455.0,
#   'TAMPINES ST 33': 465.0,
#   'BT BATOK WEST AVE 7': 85.0,
#   'JURONG WEST AVE 5': 263.0,
#   'TAMPINES AVE 7': 452.0,
#   'WOODLANDS ST 83': 551.0,
#   'CHOA CHU KANG ST 51': 133.0,
#   'PASIR RIS DR 3': 350.0,
#   'YISHUN CTRL 1': 562.0,
#   'CHOA CHU KANG AVE 1': 120.0,
#   'WOODLANDS ST 31': 546.0,
#   'BT MERAH LANE 1': 89.0,
#   'PASIR RIS ST 13': 355.0,
#   'ELIAS RD': 174.0,
#   'BISHAN ST 24': 58.0,
#   'WHAMPOA RD': 515.0,
#   'WOODLANDS ST 41': 548.0,
#   'PASIR RIS ST 71': 361.0,
#   'JURONG WEST ST 74': 279.0,
#   'PASIR RIS DR 1': 348.0,
#   'PASIR RIS ST 72': 362.0,
#   'PASIR RIS DR 10': 349.0,
#   'CHOA CHU KANG ST 52': 134.0,
#   'CLARENCE LANE': 140.0,
#   'CHOA CHU KANG NTH 6': 131.0,
#   'PASIR RIS ST 53': 360.0,
#   'CHOA CHU KANG NTH 5': 130.0,
#   'ANG MO KIO ST 21': 23.0,
#   'JLN DAMAI': 237.0,
#   'CHOA CHU KANG ST 62': 137.0,
#   'WOODLANDS AVE 5': 521.0,
#   'WOODLANDS DR 50': 532.0,
#   'CHOA CHU KANG ST 53': 135.0,
#   'TAMPINES ST 72': 474.0,
#   'UPP SERANGOON RD': 507.0,
#   'JURONG WEST ST 75': 280.0,
#   'STRATHMORE AVE': 443.0,
#   'ANG MO KIO ST 31': 24.0,
#   'TAMPINES ST 34': 466.0,
#   'YUNG AN RD': 577.0,
#   'WOODLANDS AVE 4': 520.0,
#   'CHOA CHU KANG NTH 7': 132.0,
#   'ANG MO KIO ST 11': 22.0,
#   'WOODLANDS AVE 9': 523.0,
#   'YUNG LOH RD': 580.0,
#   'CHOA CHU KANG DR': 128.0,
#   'CHOA CHU KANG ST 54': 136.0,
#   'REDHILL LANE': 386.0,
#   'KANG CHING RD': 286.0,
#   'TAH CHING RD': 447.0,
#   'SIMEI ST 5': 432.0,
#   'WOODLANDS DR 40': 529.0,
#   'WOODLANDS DR 70': 537.0,
#   'TAMPINES ST 71': 473.0,
#   'WOODLANDS DR 42': 530.0,
#   'SERANGOON NTH AVE 3': 422.0,
#   'JELAPANG RD': 229.0,
#   'BT BATOK ST 22': 72.0,
#   'HOUGANG ST 91': 224.0,
#   'WOODLANDS AVE 6': 522.0,
#   'WOODLANDS CIRCLE': 524.0,
#   'CORPORATION DR': 161.0,
#   'LOMPANG RD': 307.0,
#   'WOODLANDS DR 72': 539.0,
#   'CHOA CHU KANG ST 64': 138.0,
#   'BT BATOK ST 24': 73.0,
#   'JLN TECK WHYE': 249.0,
#   'WOODLANDS CRES': 525.0,
#   'WOODLANDS DR 60': 535.0,
#   'CHANGI VILLAGE RD': 118.0,
#   'BT BATOK ST 25': 74.0,
#   'HOUGANG AVE 9': 214.0,
#   'JURONG WEST CTRL 1': 264.0,
#   'WOODLANDS RING RD': 542.0,
#   'CHOA CHU KANG AVE 5': 124.0,
#   'TOH GUAN RD': 499.0,
#   'JURONG WEST ST 61': 272.0,
#   'WOODLANDS DR 14': 527.0,
#   'HOUGANG ST 92': 225.0,
#   'CHOA CHU KANG CRES': 126.0,
#   'SEMBAWANG CL': 399.0,
#   'CANBERRA RD': 106.0,
#   'SEMBAWANG CRES': 400.0,
#   'SEMBAWANG VISTA': 403.0,
#   'COMPASSVALE WALK': 160.0,
#   'RIVERVALE ST': 390.0,
#   'WOODLANDS DR 62': 536.0,
#   'SEMBAWANG DR': 401.0,
#   'WOODLANDS DR 53': 534.0,
#   'WOODLANDS DR 52': 533.0,
#   'RIVERVALE WALK': 391.0,
#   'COMPASSVALE LANE': 156.0,
#   'RIVERVALE DR': 389.0,
#   'SENJA RD': 413.0,
#   'JURONG WEST ST 65': 275.0,
#   'RIVERVALE CRES': 388.0,
#   'WOODLANDS DR 44': 531.0,
#   'COMPASSVALE DR': 155.0,
#   'WOODLANDS DR 16': 528.0,
#   'COMPASSVALE RD': 158.0,
#   'WOODLANDS DR 73': 540.0,
#   'HOUGANG ST 31': 219.0,
#   'JURONG WEST ST 64': 274.0,
#   'WOODLANDS DR 71': 538.0,
#   'YISHUN ST 20': 565.0,
#   'ADMIRALTY DR': 0.0,
#   'COMPASSVALE ST': 159.0,
#   'BEDOK RESERVOIR VIEW': 46.0,
#   'YUNG SHENG RD': 582.0,
#   'ADMIRALTY LINK': 1.0,
#   'SENGKANG EAST WAY': 409.0,
#   'ANG MO KIO ST 32': 25.0,
#   'ANG MO KIO ST 52': 28.0,
#   'BOON TIONG RD': 63.0,
#   'JURONG WEST ST 62': 273.0,
#   'ANCHORVALE LINK': 10.0,
#   'CANBERRA LINK': 105.0,
#   'COMPASSVALE CRES': 154.0,
#   'CLEMENTI ST 12': 148.0,
#   'MONTREAL DR': 336.0,
#   'WELLINGTON CIRCLE': 511.0,
#   'SENGKANG EAST RD': 408.0,
#   'JURONG WEST AVE 3': 262.0,
#   'ANCHORVALE LANE': 9.0,
#   'SENJA LINK': 412.0,
#   'EDGEFIELD PLAINS': 173.0,
#   'ANCHORVALE DR': 8.0,
#   'SEGAR RD': 396.0,
#   'FARRER PK RD': 180.0,
#   'PUNGGOL FIELD': 374.0,
#   'EDGEDALE PLAINS': 172.0,
#   'ANCHORVALE RD': 11.0,
#   'CANTONMENT CL': 109.0,
#   'JLN MEMBINA': 244.0,
#   'FERNVALE LANE': 182.0,
#   'JURONG WEST ST 25': 267.0,
#   'CLEMENTI ST 11': 147.0,
#   'PUNGGOL FIELD WALK': 375.0,
#   'KLANG LANE': 301.0,
#   'PUNGGOL CTRL': 371.0,
#   'JELEBU RD': 230.0,
#   'BUANGKOK CRES': 93.0,
#   'WOODLANDS DR 75': 541.0,
#   'BT BATOK WEST AVE 5': 83.0,
#   'JELLICOE RD': 231.0,
#   'PUNGGOL DR': 372.0,
#   'JURONG WEST ST 24': 266.0,
#   'SEMBAWANG WAY': 404.0,
#   'FERNVALE RD': 184.0,
#   'BUANGKOK LINK': 95.0,
#   'FERNVALE LINK': 183.0,
#   'JLN TIGA': 252.0,
#   'YUAN CHING RD': 576.0,
#   'COMPASSVALE LINK': 157.0,
#   'MARINE PARADE CTRL': 326.0,
#   'COMPASSVALE BOW': 153.0,
#   'PUNGGOL RD': 377.0,
#   'BEDOK CTRL': 34.0,
#   'PUNGGOL EAST': 373.0,
#   'SENGKANG CTRL': 406.0,
#   'TAMPINES CTRL 7': 456.0,
#   'SENGKANG WEST AVE': 410.0,
#   'PUNGGOL PL': 376.0,
#   'CANTONMENT RD': 110.0,
#   'GHIM MOH LINK': 193.0,
#   'SIMEI LANE': 427.0,
#   'YISHUN ST 41': 569.0,
#   'TELOK BLANGAH ST 31': 491.0,
#   'JLN KAYU': 240.0,
#   'LOR 1A TOA PAYOH': 309.0,
#   'PUNGGOL WALK': 378.0,
#   'SENGKANG WEST WAY': 411.0,
#   'BUANGKOK GREEN': 94.0,
#   'PUNGGOL WAY': 379.0,
#   'YISHUN ST 31': 568.0,
#   'TECK WHYE CRES': 485.0,
#   'MONTREAL LINK': 337.0,
#   'UPP SERANGOON CRES': 506.0,
#   'SUMANG LINK': 445.0,
#   'SENGKANG EAST AVE': 407.0,
#   'YISHUN AVE 1': 552.0,
#   'ANCHORVALE CRES': 7.0,
#   'ANCHORVALE ST': 12.0,
#   'TAMPINES CTRL 8': 457.0,
#   'YISHUN ST 51': 571.0,
#   'UPP SERANGOON VIEW': 508.0,
#   'TAMPINES AVE 1': 449.0,
#   'BEDOK RESERVOIR CRES': 44.0,
#   'ANG MO KIO ST 61': 29.0,
#   'DAWSON RD': 164.0,
#   'FERNVALE ST': 185.0,
#   'HOUGANG ST 32': 220.0,
#   'TAMPINES ST 86': 479.0,
#   'SUMANG WALK': 446.0,
#   'CHOA CHU KANG AVE 7': 125.0,
#   'KEAT HONG CL': 287.0,
#   'JURONG WEST CTRL 3': 265.0,
#   'KEAT HONG LINK': 288.0,
#   'ALJUNIED AVE 2': 4.0,
#   'SUMANG LANE': 444.0,
#   'CANBERRA CRES': 104.0,
#   'CANBERRA ST': 107.0,
#   'ANG MO KIO ST 44': 26.0,
#   'WOODLANDS RISE': 543.0,
#   'CANBERRA WALK': 108.0,
#   'ANG MO KIO ST 51': 27.0,
#   'BT BATOK EAST AVE 6': 69.0,
#   'BT BATOK WEST AVE 9': 87.0,
#   'TAMPINES ST 61': 472.0,
#   'YISHUN ST 43': 570.0},
#  'storey_range': {'10 TO 12': 5.0,
#   '04 TO 06': 2.0,
#   '07 TO 09': 4.0,
#   '01 TO 03': 0.0,
#   '13 TO 15': 7.0,
#   '19 TO 21': 10.0,
#   '16 TO 18': 8.0,
#   '25 TO 27': 13.0,
#   '22 TO 24': 12.0,
#   '28 TO 30': 15.0,
#   '31 TO 33': 16.0,
#   '40 TO 42': 21.0,
#   '37 TO 39': 20.0,
#   '34 TO 36': 18.0,
#   '06 TO 10': 3.0,
#   '01 TO 05': 1.0,
#   '11 TO 15': 6.0,
#   '16 TO 20': 9.0,
#   '21 TO 25': 11.0,
#   '26 TO 30': 14.0,
#   '36 TO 40': 19.0,
#   '31 TO 35': 17.0,
#   '46 TO 48': 23.0,
#   '43 TO 45': 22.0,
#   '49 TO 51': 24.0},
#  'flat_model': {'IMPROVED': 5.0,
#   'NEW GENERATION': 12.0,
#   'MODEL A': 8.0,
#   'STANDARD': 17.0,
#   'SIMPLIFIED': 16.0,
#   'MODEL A-MAISONETTE': 9.0,
#   'APARTMENT': 3.0,
#   'MAISONETTE': 7.0,
#   'TERRACE': 18.0,
#   '2-ROOM': 0.0,
#   'IMPROVED-MAISONETTE': 6.0,
#   'MULTI GENERATION': 11.0,
#   'PREMIUM APARTMENT': 13.0,
#   'ADJOINED FLAT': 2.0,
#   'PREMIUM MAISONETTE': 15.0,
#   'MODEL A2': 10.0,
#   'DBSS': 4.0,
#   'TYPE S1': 19.0,
#   'TYPE S2': 20.0,
#   'PREMIUM APARTMENT LOFT': 14.0,
#   '3GEN': 1.0},
#  'remaining_lease': {'Not Specified': 720.0,
#   '70': 358.0,
#   '65': 292.0,
#   '64': 279.0,
#   '63': 266.0,
#   '62': 253.0,
#   '69': 345.0,
#   '60': 227.0,
#   '61': 240.0,
#   '86': 566.0,
#   '77': 449.0,
#   '80': 488.0,
#   '90': 618.0,
#   '87': 579.0,
#   '66': 305.0,
#   '58': 201.0,
#   '94': 671.0,
#   '71': 371.0,
#   '68': 332.0,
#   '84': 540.0,
#   '73': 397.0,
#   '79': 475.0,
#   '76': 436.0,
#   '72': 384.0,
#   '82': 514.0,
#   '74': 410.0,
#   '67': 319.0,
#   '88': 592.0,
#   '81': 501.0,
#   '89': 605.0,
#   '53': 136.0,
#   '54': 149.0,
#   '55': 162.0,
#   '57': 188.0,
#   '93': 657.0,
#   '83': 527.0,
#   '85': 553.0,
#   '92': 644.0,
#   '91': 631.0,
#   '59': 214.0,
#   '95': 684.0,
#   '52': 123.0,
#   '51': 110.0,
#   '56': 175.0,
#   '75': 423.0,
#   '96': 698.0,
#   '78': 462.0,
#   '50': 97.0,
#   '97': 711.0,
#   '49': 84.0,
#   '48': 71.0,
#   '61 years 04 months': 245.0,
#   '60 years 07 months': 235.0,
#   '62 years 05 months': 259.0,
#   '62 years 01 month': 255.0,
#   '63 years': 267.0,
#   '61 years 06 months': 247.0,
#   '58 years 04 months': 206.0,
#   '59 years 08 months': 223.0,
#   '59 years 06 months': 221.0,
#   '60 years': 228.0,
#   '62 years 08 months': 262.0,
#   '61 years': 241.0,
#   '60 years 10 months': 238.0,
#   '59 years 03 months': 218.0,
#   '61 years 05 months': 246.0,
#   '60 years 04 months': 232.0,
#   '62 years': 254.0,
#   '60 years 03 months': 231.0,
#   '63 years 09 months': 276.0,
#   '61 years 01 month': 242.0,
#   '61 years 10 months': 251.0,
#   '58 years 06 months': 208.0,
#   '59 years 04 months': 219.0,
#   '62 years 11 months': 265.0,
#   '60 years 08 months': 236.0,
#   '93 years 08 months': 667.0,
#   '93 years 07 months': 666.0,
#   '60 years 01 month': 229.0,
#   '94 years 08 months': 680.0,
#   '78 years 04 months': 467.0,
#   '60 years 06 months': 234.0,
#   '62 years 06 months': 260.0,
#   '58 years': 202.0,
#   '70 years 08 months': 367.0,
#   '63 years 04 months': 271.0,
#   '63 years 06 months': 273.0,
#   '67 years 07 months': 327.0,
#   '61 years 07 months': 248.0,
#   '68 years 02 months': 335.0,
#   '68 years 03 months': 336.0,
#   '56 years': 176.0,
#   '67 years 09 months': 329.0,
#   '47 years 03 months': 62.0,
#   '47 years 01 month': 60.0,
#   '47 years': 59.0,
#   '46 years 11 months': 58.0,
#   '46 years 10 months': 57.0,
#   '46 years 09 months': 56.0,
#   '46 years 08 months': 55.0,
#   '66 years 0 months': 307.0,
#   '95 years 0 months': 686.0,
#   '46 years 07 months': 54.0,
#   '46 years 06 months': 53.0,
#   '46 years 03 months': 50.0,
#   '93 years 0 months': 659.0,
#   '46 years 05 months': 52.0,
#   '46 years 04 months': 51.0,
#   '46 years 01 month': 48.0,
#   '46 years 02 months': 49.0,
#   '46 years': 47.0,
#   '45 years 09 months': 44.0,
#   '45 years 11 months': 46.0,
#   '45 years 10 months': 45.0,
#   '45 years 07 months': 42.0,
#   '45 years 08 months': 43.0,
#   '97 years 01 month': 713.0,
#   '45 years 06 months': 41.0,
#   '97 years 09 months': 719.0,
#   '45 years 05 months': 40.0,
#   '45 years 04 months': 39.0,
#   '97 years': 712.0,
#   '97 years 07 months': 718.0,
#   '45 years 03 months': 38.0,
#   '45 years 02 months': 37.0,
#   '96 years 09 months': 708.0,
#   '45 years 01 month': 36.0,
#   '44 years 10 months': 33.0,
#   '97 years 05 months': 717.0,
#   '97 years 04 months': 716.0,
#   '97 years 03 months': 715.0,
#   '97 years 02 months': 714.0,
#   '45 years': 35.0,
#   '96 years 11 months': 710.0,
#   '96 years 10 months': 709.0,
#   '44 years 09 months': 32.0,
#   '44 years 08 months': 31.0,
#   '44 years 07 months': 30.0,
#   '44 years 11 months': 34.0,
#   '44 years 06 months': 29.0,
#   '44 years 05 months': 28.0,
#   '44 years 04 months': 27.0,
#   '44 years 03 months': 26.0,
#   '44 years 02 months': 25.0,
#   '44 years 01 month': 24.0,
#   '44 years': 23.0,
#   '43 years 11 months': 22.0,
#   '43 years 10 months': 21.0,
#   '43 years 09 months': 20.0,
#   '43 years 08 months': 19.0,
#   '43 years 07 months': 18.0,
#   '43 years 06 months': 17.0,
#   '43 years 05 months': 16.0,
#   '43 years 04 months': 15.0,
#   '43 years 03 months': 14.0,
#   '43 years 01 month': 12.0,
#   '43 years 02 months': 13.0,
#   '43 years': 11.0,
#   '42 years 11 months': 10.0,
#   '42 years 08 months': 7.0,
#   '42 years 07 months': 6.0,
#   '42 years 10 months': 9.0,
#   '42 years 09 months': 8.0,
#   '42 years 06 months': 5.0,
#   '42 years 05 months': 4.0,
#   '42 years 04 months': 3.0,
#   '42 years 03 months': 2.0,
#   '42 years 02 months': 1.0,
#   '42 years 01 month': 0.0}}

# %%
import json
# Write the unique_value dictionary to a JSON file with proper indentation
with open('Category_Columns_Encoded_Data.json', 'w') as file:
    json.dump(unique_value, file , indent = 4)

# %%
df1.dtypes
# Out:
# month                    int64
# town                   float64
# flat_type              float64
# block                  float64
# street_name            float64
# storey_range           float64
# floor_area_sqm         float64
# flat_model             float64
# lease_commence_date      int64
# resale_price           float64
# remaining_lease        float64
# year                     int64
# minimum_storey           int32
# maximum_storey           int32
# is_remaining_lease       int32
# floor_area_sqm_sqrt    float64
# resale_price_sqrt      float64
# dtype: object

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error,  r2_score

# %%
class regression:

    def __init__(self, x, y):
        # List of regression models to be evaluated
        self.models =[('AdaBoostRegressor', AdaBoostRegressor()),
                    #  ('RandomForestRegressor', RandomForestRegressor()),
                    #  ('ExtraTreesRegressor', ExtraTreesRegressor()),
                     ('GradientBoostingRegressor', GradientBoostingRegressor()),
                     ('HistGradientBoostingRegressor', HistGradientBoostingRegressor()),
                     ('DecisionTreeRegressor', DecisionTreeRegressor()),
                     ('XGBRegressor', XGBRegressor()),
                     ('LinearRegression', LinearRegression()),
                     ('KNeighborsRegressor', KNeighborsRegressor())
                     ]
        # Split the data into training and testing sets
        self.x_train, self.x_test, self.y_train,self.y_test = train_test_split(x,y,test_size=0.2, random_state = 42)
    
    def all_model(self):
        # Train and evaluate each model
        print(self.x_train.shape, self.x_test.shape, self.y_train.shape, self.y_test.shape)
        result = []
        for model_name, model in self.models:
            model.fit(self.x_train, self.y_train)
            y_test_pred = model.predict(self.x_test)
            y_train_pred = model.predict(self.x_train)
            
            data ={'Model_Name': model_name,
                    'Train_Mean_Square_Error': round(mean_squared_error(self.y_train, y_train_pred),4),
                    'Test_Mean_Square_Error': round(mean_squared_error(self.y_test, y_test_pred),4),
                    'Train_Mean_Absolute_Error': round(mean_absolute_error(self.y_train, y_train_pred),4),
                    'Test_Mean_Absolute_Error': round(mean_absolute_error(self.y_test, y_test_pred),4),
                    'Train_R2_Score': round(r2_score(self.y_train, y_train_pred ),4),
                    'Test_R2_Score': round(r2_score(self.y_test, y_test_pred), 4)}
            result.append(data)
            
        self.model_score_df = pd.DataFrame(result)

        return self.model_score_df

# %%
y = df1['resale_price_sqrt']
x = df1.drop(['resale_price_sqrt', 'resale_price'], axis =1)

# %%
# Create an instance of the 'regression' class with input features 'x' and target variable 'y'
regression_models = regression(x,y)
# Apply the 'all_model' method to train and evaluate various regression models
r_models = regression_models.all_model()
r_models
# Out:
# (732219, 15) (183055, 15) (732219,) (183055,)
#                       Model_Name  Train_Mean_Square_Error  \
# 0              AdaBoostRegressor                3811.8674
# 1      GradientBoostingRegressor                1438.2005
# 2  HistGradientBoostingRegressor                 616.6720
# 3          DecisionTreeRegressor                   4.1741
# 4                   XGBRegressor                 396.2742
# 5               LinearRegression                4314.6262
# 6            KNeighborsRegressor                1166.4109
# 7                   MLPRegressor                4691.6292
#
#    Test_Mean_Square_Error  Train_Mean_Absolute_Error  \
# 0               3830.0134                    49.7632
# 1               1442.9646                    28.0152
# 2                623.6784                    18.6228
# 3                607.9094                     0.3193
# 4                406.6235                    14.8893
# 5               4332.9174                    51.6743
# 6               1832.7034                    23.6857
# 7               4687.5144                    54.9432
#
#    Test_Mean_Absolute_Error  Train_R2_Score  Test_R2_Score
# 0                   49.8650          0.8276         0.8261
# 1                   28.1032          0.9350         0.9345
# 2                   18.7206          0.9721         0.9717
# 3                   17.2772          0.9998         0.9724
# 4                   15.0544          0.9821         0.9815
# 5                   51.7464          0.8049         0.8032
# 6                   29.7560          0.9473         0.9168
# 7                   54.9250          0.7879         0.7871

# %% [markdown]
# **Lowest Test MSE and MAE:**
#
# - DecisionTreeRegressor has the lowest test MSE and MAE, suggesting good performance in terms of minimizing prediction errors.
#
# **High R-squared (R2) Score:**
#
# - Models like GradientBoostingRegressor, HistGradientBoostingRegressor, and XGBRegressor have high R2 scores, indicating a good ability to explain the variance in the resale prices.
#
# - Among GradientBoostingRegressor, HistGradientBoostingRegressor, and XGBRegressor, XGBRegressor is often considered the best choice due to its superior performance, efficiency, and flexibility in handling diverse datasets.

# %%
r_models['Train_Mean_Square_Error'] - r_models['Test_Mean_Square_Error'],
# Out:
# (0    -18.1460
#  1     -4.7641
#  2     -7.0064
#  3   -603.7353
#  4    -10.3493
#  5    -18.2912
#  6   -666.2925
#  7      4.1148
#  dtype: float64,)

# %%
# Extract the training and testing sets from the instance for further analysis
x_train, x_test, y_train, y_test = regression_models.x_train, regression_models.x_test, regression_models.y_train, regression_models.y_test
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((732219, 15), (183055, 15), (732219,), (183055,))

# %%
# XGBRegressor 
model = XGBRegressor()
model.fit(x_train, y_train)
y_test_pred = model.predict(x_test)
y_train_pred = model.predict(x_train)
data ={
        'Train_Mean_Square_Error': round(mean_squared_error(y_train, y_train_pred),4),
        'Test_Mean_Square_Error': round(mean_squared_error(y_test, y_test_pred),4)}
print(data)
# Out:
# {'Train_Mean_Square_Error': 396.2742, 'Test_Mean_Square_Error': 406.6235}

# %%
# Hyperparameter tuning for XGBRegressor

# Define the parameter grid
param_grid = {
    'learning_rate': [0.1, 0.01, 0.001],
    'max_depth': [3, 4, 5],
    'n_estimators': [50, 100, 200]
}

# Create the XGBRegressor
xgb_reg = XGBRegressor()

# Use GridSearchCV to perform the search
grid_search = GridSearchCV(estimator=xgb_reg, param_grid=param_grid, scoring='neg_mean_squared_error', cv=3)
grid_result = grid_search.fit(x_train, y_train)

# Get the best parameters and the best model
best_params = grid_result.best_params_
best_model = grid_result.best_estimator_

# Evaluate the best model on the test set
y_pred = best_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error on Test Set: {mse}')
best_params
# Out:
# Mean Squared Error on Test Set: 546.9603527171982
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}

# %%
# XBGRegressore with Hyperparameter
xgb_model = XGBRegressor(learning_rate = 0.1, max_depth = 5, n_estimators = 200)
xgb_model.fit(x_train, y_train)

y_pred = xgb_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae=mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

score ={'R2': r2,
        'Mean Absolute Error': mae,
        'Mean Squared Error': mse,
        'Root Mean Squared Error': rmse}
print(score)
# Out:
# {'R2': 0.9751599722713548, 'Mean Absolute Error': 17.351893827521053, 'Mean Squared Error': 546.9603527171982, 'Root Mean Squared Error': 23.387183513993264}

# %%
# DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(x_train, y_train)
y_test_pred = model.predict(x_test)
y_train_pred = model.predict(x_train)
data ={
        'Train_Mean_Square_Error': round(mean_squared_error(y_train, y_train_pred),4),
        'Test_Mean_Square_Error': round(mean_squared_error(y_test, y_test_pred),4)}
print(data)
# Out:
# {'Train_Mean_Square_Error': 4.1741, 'Test_Mean_Square_Error': 607.421}

# %%
# Hyperparameter tuning
# Define the parameter grid
param_grid = {
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Create the DecisionTreeRegressor
tree_reg = DecisionTreeRegressor(random_state=42)

# Use GridSearchCV to perform the search
grid_search = GridSearchCV(estimator=tree_reg, param_grid=param_grid, scoring='neg_mean_squared_error', cv=3)
grid_result = grid_search.fit(x_train, y_train)

# Get the best parameters and the best model
best_params = grid_result.best_params_
best_model = grid_result.best_estimator_

# Evaluate the best model on the test set
y_pred = best_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error on Test Set: {mse}')
print(best_model, best_params)
# Out:
# Mean Squared Error on Test Set: 482.18817603474133
# DecisionTreeRegressor(min_samples_leaf=4, min_samples_split=10, random_state=42) {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10}

# %%
# DecisionTreeRegressor with Hyperparameter
decision_tree_model = DecisionTreeRegressor(min_samples_leaf=4, min_samples_split=10,)
decision_tree_model.fit(x_train, y_train)
y_pred = decision_tree_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae=mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

score ={'R2': r2,
        'Mean Absolute Error': mae,
        'Mean Squared Error': mse,
        'Root Mean Squared Error': rmse}
print(score)
# Out:
# {'R2': 0.9780919019491611, 'Mean Absolute Error': 15.393960948438275, 'Mean Squared Error': 482.4012745940434, 'Root Mean Squared Error': 21.963635277295136}

# %%
# Resale Price Prediction
data = np.array([[11, 1.0,4.0, 286.0, 39, 4.0,110.0, 5.0, 2006.0, 719, 2009.0, 7.0, 9.0, 0.0, 10.488]])
data.shape
print('XGBRegressor -> Resale Price : $', xgb_model.predict(data)[0]**2)
print('DecisionTreeRegressor -> Resale Price : $', decision_tree_model.predict(data)[0]**2)
# Out:
# XGBRegressor -> Resale Price : $ 543689.3969240822
# DecisionTreeRegressor -> Resale Price : $ 487795.89871325437

# %%
column_name = ['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range', 'floor_area_sqm', 'flat_model', 'lease_commence_date',
                'remaining_lease', 'year', 'minimum_storey', 'maximum_storey', 'is_remaining_lease', 'floor_area_sqm_sqrt', ]
test_data =df1.iloc[0: :50000][column_name].values
test_result = df1.iloc[0: :50000][['resale_price']]
dt_y=decision_tree_model.predict(test_data)**2
xgb_y = xgb_model.predict(test_data)**2

# %%
# Comparing Predicted DecisionTreeRegressor, XGBRegressor resale price with Actual resale price
pred =pd.DataFrame(zip(df1.iloc[0: :50000]['resale_price'], dt_y, xgb_y), columns= ['Actual_resale_price', 'DecisionTreeRegressor', 'XGBRegressor'])
pred['XGBRegressor_Difference'] = pred['XGBRegressor'] - pred['Actual_resale_price']
pred['DecisionTreeRegressor_Difference'] = pred['DecisionTreeRegressor'] - pred['Actual_resale_price']
pred
# Out:
#     Actual_resale_price  DecisionTreeRegressor   XGBRegressor  \
# 0                9000.0           17134.360031   18674.660156
# 1               77000.0           71611.296157   74356.226562
# 2              388000.0          317675.619755  388515.812500
# 3              163000.0          155899.113036  150882.062500
# 4              197500.0          197368.474088  192968.390625
# 5              235000.0          232477.500894  240063.312500
# 6              248000.0          247428.747927  254371.765625
# 7              255000.0          279412.644918  298285.906250
# 8              227000.0          229498.261416  241541.859375
# 9              245000.0          250626.576918  243324.859375
# 10             250000.0          248818.136015  265285.906250
# 11             390000.0          395802.679191  378839.437500
# 12             331000.0          333916.983280  357923.656250
# 13             455000.0          430928.220381  424217.031250
# 14             305000.0          300723.854615  317032.218750
# 15             433000.0          441884.398829  435988.500000
# 16             368000.0          368480.815807  376832.093750
# 17             688000.0          684841.641395  674803.500000
# 18             560000.0          530015.028932  542418.062500
#
#     XGBRegressor_Difference  DecisionTreeRegressor_Difference
# 0               9674.660156                       8134.360031
# 1              -2643.773438                      -5388.703843
# 2                515.812500                     -70324.380245
# 3             -12117.937500                      -7100.886964
# 4              -4531.609375                       -131.525912
# 5               5063.312500                      -2522.499106
# 6               6371.765625                       -571.252073
# 7              43285.906250                      24412.644918
# 8              14541.859375                       2498.261416
# 9              -1675.140625                       5626.576918
# 10             15285.906250                      -1181.863985
# 11            -11160.562500                       5802.679191
# 12             26923.656250                       2916.983280
# 13            -30782.968750                     -24071.779619
# 14             12032.218750                      -4276.145385
# 15              2988.500000                       8884.398829
# 16              8832.093750                        480.815807
# 17            -13196.500000                      -3158.358605
# 18            -17581.937500                     -29984.971068

# %%
# With help of above dataframe DecisionTreeRegressor's predicted resale price is near to the Actual resale price. Sp I am going to choose 'DecisionTreeRegressor' for resale price prediction
# Save the Decision Tree model to a file
import pickle

with open('Decision_Tree_Model.pkl', 'wb') as file:
    pickle.dump(decision_tree_model, file)

# %%
# Load the Decision Tree model from the file
with open('Decision_Tree_Model.pkl', 'rb' ) as file:
    reg_model = pickle.load(file)

# %%
# Make a prediction using the loaded model
data = np.array([[11, 1.0,4.0, 286.0, 39, 4.0,110.0, 5.0, 2006.0, 719, 2009.0, 7.0, 9.0, 0.0, 10.488]])

print( 'Resale Price : $', reg_model.predict(data)[0]**2)
# Out:
# Resale Price : $ 487795.89871325437
