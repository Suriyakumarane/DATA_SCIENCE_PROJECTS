# %%
import pandas as pd

# %%
df1 = pd.read_csv(r'C:\Users\Gayathri\OneDrive\Desktop\cardeckho\Processed_datasets\bangalore.csv')
df2 = pd.read_csv(r'C:\Users\Gayathri\OneDrive\Desktop\cardeckho\Processed_datasets\chennai.csv')
df3 = pd.read_csv(r'C:\Users\Gayathri\OneDrive\Desktop\cardeckho\Processed_datasets\delhi.csv')
df4 = pd.read_csv(r'C:\Users\Gayathri\OneDrive\Desktop\cardeckho\Processed_datasets\hyderabad.csv')
df5 = pd.read_csv(r'C:\Users\Gayathri\OneDrive\Desktop\cardeckho\Processed_datasets\jaipur.csv')
df6 = pd.read_csv(r'C:\Users\Gayathri\OneDrive\Desktop\cardeckho\Processed_datasets\kolkata.csv')

# %%
merged_df = pd.concat([df1, df2, df3, df4, df5, df6], axis = 0)

# %%
merged_df.head()
# Out:
#   manufacturer  model_year  body_type transmission_type fuel_type  total_kms  \
# 0       Maruti        2015  Hatchback            Manual    Petrol     120000
# 1         Ford        2018        SUV            Manual    Petrol      32706
# 2         Tata        2018  Hatchback            Manual    Petrol      11949
# 3      Hyundai        2014      Sedan            Manual    Petrol      17794
# 4       Maruti        2015        SUV            Manual    Diesel      60000
#
#    total_owners     price         insurance_type mileage(kmpl)  ...  \
# 0             3  400000.0  Third Party insurance     23.1 kmpl  ...
# 1             2  811000.0          Comprehensive       17 kmpl  ...
# 2             1  585000.0          Comprehensive    23.84 kmpl  ...
# 3             1  462000.0          Comprehensive     19.1 kmpl  ...
# 4             1  790000.0  Third Party insurance    23.65 kmpl  ...
#
#   number_of_cylinders valves_per_cylinder super_charger  turbo_charger  \
# ...

# %%
merged_df.shape
# Out:
# (8369, 24)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8369 entries, 0 to 1380
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   manufacturer         8369 non-null   object
#  1   model_year           8369 non-null   int64
#  2   body_type            8365 non-null   object
#  3   transmission_type    8369 non-null   object
#  4   fuel_type            8369 non-null   object
#  5   total_kms            8369 non-null   int64
#  6   total_owners         8369 non-null   int64
#  7   price                8369 non-null   float64
#  8   insurance_type       8369 non-null   object
#  9   mileage(kmpl)        8369 non-null   object
#  10  engine(CC)           8369 non-null   object
#  11  max_power(bhp)       8369 non-null   object
#  12  torque(nm)           8369 non-null   object
#  13  seats                8368 non-null   float64
#  14  number_of_cylinders  8369 non-null   int64
# ...

# %%
merged_df.to_csv(r'C:\Users\Gayathri\OneDrive\Desktop\cardeckho\merged_data.csv', index = False)
